# %% [markdown]
# ## Load libs

# %%
import sqlite3
import pandas as pd
from datetime import datetime
from pathlib import Path
import json

# %% [markdown]
# ## Load data

# %%
CSV_PATH_en_eval  = r"MLABiTe/20250704_160557/en_us/OpenAIGPT35Turbo/20250704160636_evaluations.csv"
CSV_PATH_en_global  = r"MLABiTe/20250704_160557/en_us/OpenAIGPT35Turbo/20250704160636_global_evaluation.csv"
CSV_PATH_en_resp  = r"MLABiTe/20250704_160557/en_us/OpenAIGPT35Turbo/20250704160636_responses.csv"

CSV_PATH_de_eval  = r"MLABiTe/20250704_160557/de_de/OpenAIGPT35Turbo/20250704160705_evaluations.csv"
CSV_PATH_de_global  = r"MLABiTe/20250704_160557/de_de/OpenAIGPT35Turbo/20250704160705_global_evaluation.csv"
CSV_PATH_de_resp  = r"MLABiTe/20250704_160557/de_de/OpenAIGPT35Turbo/20250704160705_responses.csv"

CSV_PATH_fr_eval  = r"MLABiTe/20250704_160557/fr_fr/OpenAIGPT35Turbo/20250704160656_evaluations.csv"
CSV_PATH_fr_global  = r"MLABiTe/20250704_160557/fr_fr/OpenAIGPT35Turbo/20250704160656_global_evaluation.csv"
CSV_PATH_fr_resp  = r"MLABiTe/20250704_160557/fr_fr/OpenAIGPT35Turbo/20250704160656_responses.csv"

CSV_PATH_lu_eval  = r"MLABiTe/20250704_160557/lu_lu/OpenAIGPT35Turbo/20250704160732_evaluations.csv"
CSV_PATH_lu_global  = r"MLABiTe/20250704_160557/lu_lu/OpenAIGPT35Turbo/20250704160732_global_evaluation.csv"
CSV_PATH_lu_resp  = r"MLABiTe/20250704_160557/lu_lu/OpenAIGPT35Turbo/20250704160731_responses.csv"

# %%
df_mlaBite_en_eval = pd.read_csv(CSV_PATH_en_eval, sep = ';')
df_mlaBite_en_global = pd.read_csv(CSV_PATH_en_global, sep = ';')
df_mlaBite_en_resp = pd.read_csv(CSV_PATH_en_resp, sep = ';')

# %%
print(df_mlaBite_en_eval.columns)
print(df_mlaBite_en_global.columns)
print(df_mlaBite_en_resp.columns)
# Out:
# Index(['Provider', 'Model', 'Concern', 'Language', 'Input Type',
#        'Reflection Type', 'Template', 'Oracle Evaluation', 'Oracle Prediction',
#        'Evaluation'],
#       dtype='object')
# Index(['Provider', 'Model', 'Concern', 'Language', 'Input Type',
#        'Reflection Type', 'Passed Nr', 'Failed Nr', 'Error Nr', 'Passed Pct',
#        'Failed Pct', 'Total', 'Tolerance', 'Tolerance Evaluation'],
#       dtype='object')
# Index(['Provider', 'Model', 'Instance', 'Response'], dtype='object')

# %%
df_mlaBite_de_eval = pd.read_csv(CSV_PATH_de_eval, sep = ';')
df_mlaBite_de_global = pd.read_csv(CSV_PATH_de_global, sep = ';')
df_mlaBite_de_resp = pd.read_csv(CSV_PATH_de_resp, sep = ';')

# %%
df_mlaBite_fr_eval = pd.read_csv(CSV_PATH_fr_eval, sep = ';')
df_mlaBite_fr_global = pd.read_csv(CSV_PATH_fr_global, sep = ';')
df_mlaBite_fr_resp = pd.read_csv(CSV_PATH_fr_resp, sep = ';')

# %%
df_mlaBite_lu_eval = pd.read_csv(CSV_PATH_lu_eval, sep = ';')
df_mlaBite_lu_global = pd.read_csv(CSV_PATH_lu_global, sep = ';')
df_mlaBite_lu_resp = pd.read_csv(CSV_PATH_lu_resp, sep = ';')
